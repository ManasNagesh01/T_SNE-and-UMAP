# %%
# !pip install umap-learn==0.5.7
# Out:
# ...
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/57.7 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/57.7 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/57.7 kB ? eta -:--:--
# ...
